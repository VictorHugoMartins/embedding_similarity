# %% [markdown]
# # Trabalho Prático 1 - Processamento de Linguagem Natural
#
# **Discente**: Victor Hugo Martins
#
# **Professor**: Adriano Veloso

# %% [markdown]
# ## Objetivo Geral
#
# Este projeto tem como objetivo produzir e avaliar modelos de linguagem neural. A qualidade desses modelos depende dos hiperparâmetros utilizados. A habilidade a ser exercitada neste trabalho prático é a escolha adequada dos hiperparâmetros de um modelo de linguagem. Portanto, mais especificamente, serão produzidos diversos modelos de linguagem, cada um deles obtidos com diferentes hiperparâmetros, e em seguida você deverá avaliar cada modelo através de uma aplicação de analogias (descrita a seguir). Por fim, você deverá concluir a respeito dos melhores hiperparâmetros para o modelo de linguagem. Os hiperparâmetros a serem considerados são:
#
# * CBOW ou Skip-gram
# * Tamanho da janela de contexto
# * Tamanho do embedding
# * Quantidade de iterações de treinamento.
#
# Ao fim da execução, os resultados obtidos serão analisados.

# %% [markdown]
# # Implementação

# %% [markdown]
# ## Corpus
#
# Nessa etapa, ocorre o download do dataset usado e construção do corpus a partir dele.
#
# Um *corpus* é um conjunto de textos que serve como base de dados para análise e modelagem linguística. Ele é criado para representar um idioma ou contexto específico e pode incluir palavras, frases, sentenças ou até mesmo documentos completos. Dentro da tarefa proposta, o corpus será utilizado para treinar os dados dos modelos *Word2Vec* com um vocabulário amplo.
#
# O *corpus* utilizado é o **Text8**, que contém os primeiros 100 milhões de caracteres da *Wikipédia* em lingua inglessa (edição de 2001), sendo restrito a letras minúsculas e sem pontuação. Seu vocabulário compacto e cheio de significado o torna útil em tarefas não apenas de similaridade semântica, mas também modelagem de tópicos e classificação de textos. Seu tamanho o tornam menos custoso em termos computacionais.

# %%
import os
import urllib.request
import zipfile

def download_text8():
    url = "http://mattmahoney.net/dc/text8.zip"
    local_filename = "text8.zip"

    if not os.path.exists("text8"):
        print("Baixando o dataset text8...")
        urllib.request.urlretrieve(url, local_filename)

        with zipfile.ZipFile(local_filename, 'r') as zip_ref:
            zip_ref.extractall(".")
        print("Dataset extraído com sucesso!")

        os.remove(local_filename)

download_text8()

# %%
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.test.utils import datapath
import numpy as np

def load_and_preprocess_corpus(filepath):
    with open(filepath, 'r') as file:
        corpus = file.read().splitlines()
    return [line.split() for line in corpus]

# %% [markdown]
# O arquivo questions-words.txt é amplamente utilizado como um benchmark para avaliar modelos de vetorização de palavras, como Word2Vec. Ele contém pares de palavras e relações semânticas ou sintáticas organizadas em categorias. A ideia é testar a capacidade do modelo de capturar relações entre palavras usando operações vetoriais.
#
# O teste clássico é baseado na ideia de analogia de palavras, como:
# "Rei está para Rainha assim como Homem está para Mulher".
# Matematicamente, isso é expresso como:
# vec
# (
# 𝑟
# 𝑒
# 𝑖
# )
# −
# vec
# (
# ℎ
# 𝑜
# 𝑚
# 𝑒
# 𝑚
# )
# +
# vec
# (
# 𝑚
# 𝑢
# 𝑙
# ℎ
# 𝑒
# 𝑟
# )
# ≈
# vec
# (
# 𝑟
# 𝑎
# 𝑖
# 𝑛
# ℎ
# 𝑎
# )
#
# O modelo é avaliado em quão bem ele encontra word4 ao operar sobre os vetores de word1, word2 e word3.

# %%
import os
from sklearn.decomposition import PCA
import requests

def download_analogy_file(analogy_path):
    url = "https://raw.githubusercontent.com/tmikolov/word2vec/master/questions-words.txt"
    if not os.path.exists(analogy_path):
        print("Baixando o arquivo de analogias...")
        response = requests.get(url)
        with open(analogy_path, "wb") as f:
            f.write(response.content)
        print("Download concluído.")

# %%
# Variáveis de arquivos gerais
corpus_path = "text8"
analogy_path = "questions-words.txt"
download_analogy_file(analogy_path)
corpus = load_and_preprocess_corpus(corpus_path)

# %% [markdown]
# ## Avaliação
#
# O intuito é avaliar as analogias em torno de sua distância. Distâncias menores demonstram maior similaridade entre as palavras. Portanto, quão menor a distância, melhor o modelo é avaliado.
#
# Para avaliar analogias com distância mínima entre vetores em embeddings (e, intrisecamente, capturar relações semânticas e sintáticas), utiliza-se a geometria do espaço vetorial.
#
# Essa abordagem funciona porque palavras relacionadas estão mais próximas no espaço, e a distância ou similaridade do cosseno identifica o vetor mais próximo do resultado da analogia.

# %%
# Avaliar a distância média de analogias
def evaluate_distance(model, analogy_path, apply_pca_flag, pca_components=0):
    word_vectors = model.wv.vectors
    word_to_index = model.wv.key_to_index

    if apply_pca_flag:
        word_vectors = apply_pca(word_vectors, n_components=pca_components)

    analogy_file = datapath(analogy_path)
    total_distance = 0
    valid_pairs = 0

    with open(analogy_file, "r") as f:
        for line in f:
            if line.startswith(":"):  # ignore categories
                continue
            words = line.strip().split()
            if all(word in word_to_index for word in words):
                idx_a, idx_b, idx_c, idx_d = [word_to_index[word] for word in words]
                vec_a, vec_b, vec_c, vec_d = (
                    word_vectors[idx_a],
                    word_vectors[idx_b],
                    word_vectors[idx_c],
                    word_vectors[idx_d],
                )
                predicted_vec = vec_c + (vec_b - vec_a)
                distance = np.linalg.norm(predicted_vec - vec_d)
                total_distance += distance
                valid_pairs += 1

    average_distance = total_distance / valid_pairs if valid_pairs > 0 else float("inf")
    return average_distance

# %% [markdown]
# **Grid Search** é uma técnica para identificar a melhor combinação de hiperparâmetros para um modelo. A escolha adequada de hiperparâmetros é crucial porque afeta diretamente o desempenho do modelo. Para cada combinação de hiperparâmetros no espaço definido, o modelo é treinado e avaliado com os dados fornecidos. A cada execução, o desempenho do modelo é avaliado usando uma métrica específica, que será usada para comparar os resultados das diferentes combinações.
#
# Após avaliar todas as combinações, o conjunto de hiperparâmetros que maximiza ou minimiza a métrica escolhida é identificado como o melhor.
#
# Além de contribuir para essa identificação, o Grid Search também atuam como **validação cruzada**.
#
# A grade de parâmetros escolhida está definida abaixo:

# %%
# Grid de parâmetros
param_grid = {
    "model_type": ["Skip-gram", "CBOW"],
    "context_size": [2, 3, 4, 5],
    "embedding_dim": [5, 20, 25, 50, 100],
    "num_epochs": [3, 5, 7, 10],
    "apply_pca_flag": [True, False],
    "pca_components": [2, 3, 5],  # Número de componentes para PCA
    "workers": [3],  # Número de componentes para PCA
}

# %% [markdown]
# E sua implementação:

# %%
from itertools import product
import pandas as pd

def grid_search_word2vec(corpus, analogy_path, param_grid):
    best_params = None
    best_score = float("inf")
    results = []
    trained_models = {}  # Cache para modelos já treinados
    evaluation_cache = {}  # Cache para resultados de avaliação

    for params in product(*param_grid.values()):
        model_type, context_size, embedding_dim, num_epochs, apply_pca_flag, pca_components, workers = params

        # Ignorar variações de PCA components se PCA não for aplicado
        if not apply_pca_flag:
            pca_components = None

        # Criar uma chave única para identificar o modelo e incluir workers
        model_key = (model_type, context_size, embedding_dim, num_epochs, workers)
        eval_key = (model_key, apply_pca_flag, pca_components)

        # Treinar o modelo apenas se ainda não foi treinado para esta combinação
        if model_key not in trained_models:
            print(f"Treinando modelo com parâmetros: {model_key}")
            trained_models[model_key] = train_word2vec(
                corpus, model_type, context_size, embedding_dim, num_epochs, workers
            )

        model = trained_models[model_key]

        # Avaliar apenas se a avaliação para essa configuração ainda não foi feita
        if eval_key not in evaluation_cache:
            avg_distance = evaluate_distance(model, analogy_path, apply_pca_flag, pca_components)
            evaluation_cache[eval_key] = avg_distance
        else:
            avg_distance = evaluation_cache[eval_key]

        results.append({
            "Modelo": model_type,
            "Contexto": context_size,
            "Dimensão Embedding": embedding_dim,
            "Épocas": num_epochs,
            "Workers": workers,
            "PCA Aplicado": apply_pca_flag,
            "Componentes PCA": pca_components if apply_pca_flag else "Não Aplicado",
            "Distância Média": avg_distance
        })

        if avg_distance < best_score:
            best_score = avg_distance
            best_params = params

        print(f"Parâmetros: {params}, Distância média: {avg_distance:.4f}")

    df_results = pd.DataFrame(results)
    grouped_results = df_results.sort_values(by=["Modelo", "PCA Aplicado", "Distância Média"])

    return best_params, grouped_results

# %% [markdown]
# Um detalhe sobre essa implementação é o uso de chaves que evitem que o mesmo modelo seja treinado mais de uma vez. Caso isso não fosse trato, essa situação ocorreria para o caso do PCA não ser utilizado, onde a quantidade de componentes referentes a ele seria irrelevante. Com a adição das chaves, o custo computacional é reduzido ao não calcular mais de uma vez um mesmo modelo (ou seja, um modelo definido pelas tuplas de parâmetros).
#
# Nas seções a seguir, serão abordados os parâmetros escolhidos para o Grid.

# %% [markdown]
# ## PCA
#
# PCA é um método de normalização que busca reduzir a dimensionalidade dos dados com o objetivo de facilitar a visualização e generalização do modelo. Apesar dessa proposta, que viria a diminuir o desempenho computacional do modelo, é possível que a aplicação de PCA faça com que os dados percam informações significativas e com que o modelo falhe a identificar relações não lineares.
#
# Tendo essa dúvida em mente, a normalização por PCA também foi adicionada como um dos "parâmetros" para o GridSearch (mais detalhes sobre esse método e o porquê de sua escolha vem a seguir), buscando comparar se, para a tarefa de analogias especificamente, é mais vantajoso usar ou não deste método.

# %%
from sklearn.decomposition import PCA

# Reduzir dimensionalidade com PCA
def apply_pca(vectors, n_components):
    pca = PCA(n_components=n_components)
    reduced_vectors = pca.fit_transform(vectors)
    return reduced_vectors

# %% [markdown]
# ## Skip-Gram e CBOW
#
# Skip-Gram e CBOW (Continuous Bag of Words) são arquiteturas utilizadas em modelos de representações vetoriais densas, como Word2Vec, para aprender representações vetoriais de palavras. Apesar de ambos identificarem relações sintáticas e semânticas, de forma que a aplicação de ambos se torne possível em tarefas de previsão de analogias, eles possuem especificidades e objetivos distintos.
#
# * **CBOW (Continuous Bag of Words)**
#
# Prediz uma palavra central a partir do contexto que a cerca.
#
# Prediz uma palavra-alvo com base no contexto (as palavras que a cercam). Dentre as suas vantagens, estão o treinamento rápido e a eficiência em conjunto de dados menores. Como, em sua implementação, faz uso das médias dos vetores do contexto, essa arquitetura pode ser menor eficaz em capturar palavras raras.
#
# * **Skip-Gram**
#
# Prediz as palavras do contexto com base em uma palavra-central.
#
# Em comparação com o CBOW, esta arquitetura atua melhor na captura de palavras raras, por possuir a capacidade de aprender relações específicas e mais detalhes entre palavra(s) e contexto. Entretanto, seu treinamento se dá de forma mais lenta.

# %%
from gensim.models import Word2Vec
from gensim.test.utils import datapath
import numpy as np

# Treinar o modelo Word2Vec
def train_word2vec(corpus, model_type, context_size, embedding_dim, num_epochs, num_workers):
    sg = 1 if model_type == "Skip-gram" else 0  # 1 para Skip-gram, 0 para CBOW
    model = Word2Vec(
        sentences=corpus,
        vector_size=embedding_dim,
        window=context_size,
        sg=sg,
        epochs=num_epochs,
        workers=num_workers
    )
    return model

# %% [markdown]
# ## Busca pelos Resultados
#
# Abaixo, a Grid Search é executada, a fim de identificar quais os melhores (e piores) hiperparâmetros para o modelo proposto.

# %%
print("Iniciando grid search...")
best_params, results_df = grid_search_word2vec(corpus, analogy_path, param_grid)
# Out:
# Iniciando grid search...
# Treinando modelo com parâmetros: ('Skip-gram', 2, 5, 3, 3)
# Parâmetros: ('Skip-gram', 2, 5, 3, True, 2, 3), Distância média: 0.2906
# Parâmetros: ('Skip-gram', 2, 5, 3, True, 3, 3), Distância média: 0.3717
# Parâmetros: ('Skip-gram', 2, 5, 3, True, 5, 3), Distância média: 0.4959
# Parâmetros: ('Skip-gram', 2, 5, 3, False, 2, 3), Distância média: 0.4959
# Parâmetros: ('Skip-gram', 2, 5, 3, False, 3, 3), Distância média: 0.4959
# Parâmetros: ('Skip-gram', 2, 5, 3, False, 5, 3), Distância média: 0.4959
# Treinando modelo com parâmetros: ('Skip-gram', 2, 5, 5, 3)
# Parâmetros: ('Skip-gram', 2, 5, 5, True, 2, 3), Distância média: 0.3220
# Parâmetros: ('Skip-gram', 2, 5, 5, True, 3, 3), Distância média: 0.3994
# Parâmetros: ('Skip-gram', 2, 5, 5, True, 5, 3), Distância média: 0.5190
# Parâmetros: ('Skip-gram', 2, 5, 5, False, 2, 3), Distância média: 0.5190
# Parâmetros: ('Skip-gram', 2, 5, 5, False, 3, 3), Distância média: 0.5190
# Parâmetros: ('Skip-gram', 2, 5, 5, False, 5, 3), Distância média: 0.5190
# Treinando modelo com parâmetros: ('Skip-gram', 2, 5, 7, 3)
# Parâmetros: ('Skip-gram', 2, 5, 7, True, 2, 3), Distância média: 0.3652
# Parâmetros: ('Skip-gram', 2, 5, 7, True, 3, 3), Distância média: 0.4380
# Parâmetros: ('Skip-gram', 2, 5, 7, True, 5, 3), Distância média: 0.5522
# Parâmetros: ('Skip-gram', 2, 5, 7, False, 2, 3), Distância média: 0.5522
# Parâmetros: ('Skip-gram', 2, 5, 7, False, 3, 3), Distância média: 0.5522
# Parâmetros: ('Skip-gram', 2, 5, 7, False, 5, 3), Distância média: 0.5522
# Treinando modelo com parâmetros: ('Skip-gram', 2, 5, 10, 3)
# Parâmetros: ('Skip-gram', 2, 5, 10, True, 2, 3), Distância média: 0.4464
# Parâmetros: ('Skip-gram', 2, 5, 10, True, 3, 3), Distância média: 0.5124
# Parâmetros: ('Skip-gram', 2, 5, 10, True, 5, 3), Distância média: 0.6188
# Parâmetros: ('Skip-gram', 2, 5, 10, False, 2, 3), Distância média: 0.6188
# Parâmetros: ('Skip-gram', 2, 5, 10, False, 3, 3), Distância média: 0.6188
# Parâmetros: ('Skip-gram', 2, 5, 10, False, 5, 3), Distância média: 0.6188
# Treinando modelo com parâmetros: ('Skip-gram', 2, 20, 3, 3)
# Parâmetros: ('Skip-gram', 2, 20, 3, True, 2, 3), Distância média: 0.0865
# Parâmetros: ('Skip-gram', 2, 20, 3, True, 3, 3), Distância média: 0.1059
# Parâmetros: ('Skip-gram', 2, 20, 3, True, 5, 3), Distância média: 0.1350
# Parâmetros: ('Skip-gram', 2, 20, 3, False, 2, 3), Distância média: 0.2601
# Parâmetros: ('Skip-gram', 2, 20, 3, False, 3, 3), Distância média: 0.2601
# Parâmetros: ('Skip-gram', 2, 20, 3, False, 5, 3), Distância média: 0.2601
# Treinando modelo com parâmetros: ('Skip-gram', 2, 20, 5, 3)
# Parâmetros: ('Skip-gram', 2, 20, 5, True, 2, 3), Distância média: 0.1352
# Parâmetros: ('Skip-gram', 2, 20, 5, True, 3, 3), Distância média: 0.1514
# Parâmetros: ('Skip-gram', 2, 20, 5, True, 5, 3), Distância média: 0.1765
# Parâmetros: ('Skip-gram', 2, 20, 5, False, 2, 3), Distância média: 0.2910
# Parâmetros: ('Skip-gram', 2, 20, 5, False, 3, 3), Distância média: 0.2910
# Parâmetros: ('Skip-gram', 2, 20, 5, False, 5, 3), Distância média: 0.2910
# Treinando modelo com parâmetros: ('Skip-gram', 2, 20, 7, 3)
# Parâmetros: ('Skip-gram', 2, 20, 7, True, 2, 3), Distância média: 0.1958
# Parâmetros: ('Skip-gram', 2, 20, 7, True, 3, 3), Distância média: 0.2094
# Parâmetros: ('Skip-gram', 2, 20, 7, True, 5, 3), Distância média: 0.2312
# Parâmetros: ('Skip-gram', 2, 20, 7, False, 2, 3), Distância média: 0.3346
# Parâmetros: ('Skip-gram', 2, 20, 7, False, 3, 3), Distância média: 0.3346
# Parâmetros: ('Skip-gram', 2, 20, 7, False, 5, 3), Distância média: 0.3346
# Treinando modelo com parâmetros: ('Skip-gram', 2, 20, 10, 3)
# Parâmetros: ('Skip-gram', 2, 20, 10, True, 2, 3), Distância média: 0.2946
# Parâmetros: ('Skip-gram', 2, 20, 10, True, 3, 3), Distância média: 0.3061
# Parâmetros: ('Skip-gram', 2, 20, 10, True, 5, 3), Distância média: 0.3245
# Parâmetros: ('Skip-gram', 2, 20, 10, False, 2, 3), Distância média: 0.4153
# Parâmetros: ('Skip-gram', 2, 20, 10, False, 3, 3), Distância média: 0.4153
# Parâmetros: ('Skip-gram', 2, 20, 10, False, 5, 3), Distância média: 0.4153
# Treinando modelo com parâmetros: ('Skip-gram', 2, 25, 3, 3)
# Parâmetros: ('Skip-gram', 2, 25, 3, True, 2, 3), Distância média: 0.0651
# Parâmetros: ('Skip-gram', 2, 25, 3, True, 3, 3), Distância média: 0.0821
# Parâmetros: ('Skip-gram', 2, 25, 3, True, 5, 3), Distância média: 0.1062
# Parâmetros: ('Skip-gram', 2, 25, 3, False, 2, 3), Distância média: 0.2336
# Parâmetros: ('Skip-gram', 2, 25, 3, False, 3, 3), Distância média: 0.2336
# Parâmetros: ('Skip-gram', 2, 25, 3, False, 5, 3), Distância média: 0.2336
# Treinando modelo com parâmetros: ('Skip-gram', 2, 25, 5, 3)
# Parâmetros: ('Skip-gram', 2, 25, 5, True, 2, 3), Distância média: 0.1097
# Parâmetros: ('Skip-gram', 2, 25, 5, True, 3, 3), Distância média: 0.1236
# Parâmetros: ('Skip-gram', 2, 25, 5, True, 5, 3), Distância média: 0.1444
# Parâmetros: ('Skip-gram', 2, 25, 5, False, 2, 3), Distância média: 0.2607
# Parâmetros: ('Skip-gram', 2, 25, 5, False, 3, 3), Distância média: 0.2607
# Parâmetros: ('Skip-gram', 2, 25, 5, False, 5, 3), Distância média: 0.2607
# Treinando modelo com parâmetros: ('Skip-gram', 2, 25, 7, 3)
# Parâmetros: ('Skip-gram', 2, 25, 7, True, 2, 3), Distância média: 0.1716
# Parâmetros: ('Skip-gram', 2, 25, 7, True, 3, 3), Distância média: 0.1826
# Parâmetros: ('Skip-gram', 2, 25, 7, True, 5, 3), Distância média: 0.2004
# Parâmetros: ('Skip-gram', 2, 25, 7, False, 2, 3), Distância média: 0.3041
# Parâmetros: ('Skip-gram', 2, 25, 7, False, 3, 3), Distância média: 0.3041
# Parâmetros: ('Skip-gram', 2, 25, 7, False, 5, 3), Distância média: 0.3041
# Treinando modelo com parâmetros: ('Skip-gram', 2, 25, 10, 3)
# Parâmetros: ('Skip-gram', 2, 25, 10, True, 2, 3), Distância média: 0.2716
# Parâmetros: ('Skip-gram', 2, 25, 10, True, 3, 3), Distância média: 0.2803
# Parâmetros: ('Skip-gram', 2, 25, 10, True, 5, 3), Distância média: 0.2956
# Parâmetros: ('Skip-gram', 2, 25, 10, False, 2, 3), Distância média: 0.3856
# Parâmetros: ('Skip-gram', 2, 25, 10, False, 3, 3), Distância média: 0.3856
# Parâmetros: ('Skip-gram', 2, 25, 10, False, 5, 3), Distância média: 0.3856
# Treinando modelo com parâmetros: ('Skip-gram', 2, 50, 3, 3)
# Parâmetros: ('Skip-gram', 2, 50, 3, True, 2, 3), Distância média: 0.0407
# Parâmetros: ('Skip-gram', 2, 50, 3, True, 3, 3), Distância média: 0.0483
# Parâmetros: ('Skip-gram', 2, 50, 3, True, 5, 3), Distância média: 0.0596
# Parâmetros: ('Skip-gram', 2, 50, 3, False, 2, 3), Distância média: 0.1678
# Parâmetros: ('Skip-gram', 2, 50, 3, False, 3, 3), Distância média: 0.1678
# Parâmetros: ('Skip-gram', 2, 50, 3, False, 5, 3), Distância média: 0.1678
# Treinando modelo com parâmetros: ('Skip-gram', 2, 50, 5, 3)
# Parâmetros: ('Skip-gram', 2, 50, 5, True, 2, 3), Distância média: 0.0913
# Parâmetros: ('Skip-gram', 2, 50, 5, True, 3, 3), Distância média: 0.0970
# Parâmetros: ('Skip-gram', 2, 50, 5, True, 5, 3), Distância média: 0.1056
# Parâmetros: ('Skip-gram', 2, 50, 5, False, 2, 3), Distância média: 0.1992
# Parâmetros: ('Skip-gram', 2, 50, 5, False, 3, 3), Distância média: 0.1992
# Parâmetros: ('Skip-gram', 2, 50, 5, False, 5, 3), Distância média: 0.1992
# Treinando modelo com parâmetros: ('Skip-gram', 2, 50, 7, 3)
# Parâmetros: ('Skip-gram', 2, 50, 7, True, 2, 3), Distância média: 0.1568
# Parâmetros: ('Skip-gram', 2, 50, 7, True, 3, 3), Distância média: 0.1614
# Parâmetros: ('Skip-gram', 2, 50, 7, True, 5, 3), Distância média: 0.1682
# Parâmetros: ('Skip-gram', 2, 50, 7, False, 2, 3), Distância média: 0.2482
# Parâmetros: ('Skip-gram', 2, 50, 7, False, 3, 3), Distância média: 0.2482
# Parâmetros: ('Skip-gram', 2, 50, 7, False, 5, 3), Distância média: 0.2482
# Treinando modelo com parâmetros: ('Skip-gram', 2, 50, 10, 3)
# Parâmetros: ('Skip-gram', 2, 50, 10, True, 2, 3), Distância média: 0.2592
# Parâmetros: ('Skip-gram', 2, 50, 10, True, 3, 3), Distância média: 0.2627
# Parâmetros: ('Skip-gram', 2, 50, 10, True, 5, 3), Distância média: 0.2686
# Parâmetros: ('Skip-gram', 2, 50, 10, False, 2, 3), Distância média: 0.3362
# Parâmetros: ('Skip-gram', 2, 50, 10, False, 3, 3), Distância média: 0.3362
# Parâmetros: ('Skip-gram', 2, 50, 10, False, 5, 3), Distância média: 0.3362
# Treinando modelo com parâmetros: ('Skip-gram', 2, 100, 3, 3)
# Parâmetros: ('Skip-gram', 2, 100, 3, True, 2, 3), Distância média: 0.0238
# Parâmetros: ('Skip-gram', 2, 100, 3, True, 3, 3), Distância média: 0.0277
# Parâmetros: ('Skip-gram', 2, 100, 3, True, 5, 3), Distância média: 0.0333
# Parâmetros: ('Skip-gram', 2, 100, 3, False, 2, 3), Distância média: 0.1181
# Parâmetros: ('Skip-gram', 2, 100, 3, False, 3, 3), Distância média: 0.1181
# Parâmetros: ('Skip-gram', 2, 100, 3, False, 5, 3), Distância média: 0.1181
# Treinando modelo com parâmetros: ('Skip-gram', 2, 100, 5, 3)
# Parâmetros: ('Skip-gram', 2, 100, 5, True, 2, 3), Distância média: 0.0712
# Parâmetros: ('Skip-gram', 2, 100, 5, True, 3, 3), Distância média: 0.0738
# Parâmetros: ('Skip-gram', 2, 100, 5, True, 5, 3), Distância média: 0.0777
# Parâmetros: ('Skip-gram', 2, 100, 5, False, 2, 3), Distância média: 0.1480
# Parâmetros: ('Skip-gram', 2, 100, 5, False, 3, 3), Distância média: 0.1480
# Parâmetros: ('Skip-gram', 2, 100, 5, False, 5, 3), Distância média: 0.1480
# Treinando modelo com parâmetros: ('Skip-gram', 2, 100, 7, 3)
# Parâmetros: ('Skip-gram', 2, 100, 7, True, 2, 3), Distância média: 0.1381
# Parâmetros: ('Skip-gram', 2, 100, 7, True, 3, 3), Distância média: 0.1401
# Parâmetros: ('Skip-gram', 2, 100, 7, True, 5, 3), Distância média: 0.1432
# Parâmetros: ('Skip-gram', 2, 100, 7, False, 2, 3), Distância média: 0.2009
# Parâmetros: ('Skip-gram', 2, 100, 7, False, 3, 3), Distância média: 0.2009
# Parâmetros: ('Skip-gram', 2, 100, 7, False, 5, 3), Distância média: 0.2009
# Treinando modelo com parâmetros: ('Skip-gram', 2, 100, 10, 3)
# Parâmetros: ('Skip-gram', 2, 100, 10, True, 2, 3), Distância média: 0.2410
# Parâmetros: ('Skip-gram', 2, 100, 10, True, 3, 3), Distância média: 0.2426
# Parâmetros: ('Skip-gram', 2, 100, 10, True, 5, 3), Distância média: 0.2454
# Parâmetros: ('Skip-gram', 2, 100, 10, False, 2, 3), Distância média: 0.2936
# Parâmetros: ('Skip-gram', 2, 100, 10, False, 3, 3), Distância média: 0.2936
# Parâmetros: ('Skip-gram', 2, 100, 10, False, 5, 3), Distância média: 0.2936
# Treinando modelo com parâmetros: ('Skip-gram', 3, 5, 3, 3)
# Parâmetros: ('Skip-gram', 3, 5, 3, True, 2, 3), Distância média: 0.3139
# Parâmetros: ('Skip-gram', 3, 5, 3, True, 3, 3), Distância média: 0.3922
# Parâmetros: ('Skip-gram', 3, 5, 3, True, 5, 3), Distância média: 0.5125
# Parâmetros: ('Skip-gram', 3, 5, 3, False, 2, 3), Distância média: 0.5125
# Parâmetros: ('Skip-gram', 3, 5, 3, False, 3, 3), Distância média: 0.5125
# Parâmetros: ('Skip-gram', 3, 5, 3, False, 5, 3), Distância média: 0.5125
# Treinando modelo com parâmetros: ('Skip-gram', 3, 5, 5, 3)
# Parâmetros: ('Skip-gram', 3, 5, 5, True, 2, 3), Distância média: 0.3707
# Parâmetros: ('Skip-gram', 3, 5, 5, True, 3, 3), Distância média: 0.4434
# Parâmetros: ('Skip-gram', 3, 5, 5, True, 5, 3), Distância média: 0.5565
# Parâmetros: ('Skip-gram', 3, 5, 5, False, 2, 3), Distância média: 0.5565
# Parâmetros: ('Skip-gram', 3, 5, 5, False, 3, 3), Distância média: 0.5565
# Parâmetros: ('Skip-gram', 3, 5, 5, False, 5, 3), Distância média: 0.5565
# Treinando modelo com parâmetros: ('Skip-gram', 3, 5, 7, 3)
# Parâmetros: ('Skip-gram', 3, 5, 7, True, 2, 3), Distância média: 0.4402
# Parâmetros: ('Skip-gram', 3, 5, 7, True, 3, 3), Distância média: 0.5074
# Parâmetros: ('Skip-gram', 3, 5, 7, True, 5, 3), Distância média: 0.6138
# Parâmetros: ('Skip-gram', 3, 5, 7, False, 2, 3), Distância média: 0.6138
# Parâmetros: ('Skip-gram', 3, 5, 7, False, 3, 3), Distância média: 0.6138
# Parâmetros: ('Skip-gram', 3, 5, 7, False, 5, 3), Distância média: 0.6138
# Treinando modelo com parâmetros: ('Skip-gram', 3, 5, 10, 3)
# Parâmetros: ('Skip-gram', 3, 5, 10, True, 2, 3), Distância média: 0.5548
# Parâmetros: ('Skip-gram', 3, 5, 10, True, 3, 3), Distância média: 0.6146
# Parâmetros: ('Skip-gram', 3, 5, 10, True, 5, 3), Distância média: 0.7126
# Parâmetros: ('Skip-gram', 3, 5, 10, False, 2, 3), Distância média: 0.7126
# Parâmetros: ('Skip-gram', 3, 5, 10, False, 3, 3), Distância média: 0.7126
# Parâmetros: ('Skip-gram', 3, 5, 10, False, 5, 3), Distância média: 0.7126
# Treinando modelo com parâmetros: ('Skip-gram', 3, 20, 3, 3)
# Parâmetros: ('Skip-gram', 3, 20, 3, True, 2, 3), Distância média: 0.1176
# Parâmetros: ('Skip-gram', 3, 20, 3, True, 3, 3), Distância média: 0.1347
# Parâmetros: ('Skip-gram', 3, 20, 3, True, 5, 3), Distância média: 0.1611
# Parâmetros: ('Skip-gram', 3, 20, 3, False, 2, 3), Distância média: 0.2792
# Parâmetros: ('Skip-gram', 3, 20, 3, False, 3, 3), Distância média: 0.2792
# Parâmetros: ('Skip-gram', 3, 20, 3, False, 5, 3), Distância média: 0.2792
# Treinando modelo com parâmetros: ('Skip-gram', 3, 20, 5, 3)
# Parâmetros: ('Skip-gram', 3, 20, 5, True, 2, 3), Distância média: 0.1946
# Parâmetros: ('Skip-gram', 3, 20, 5, True, 3, 3), Distância média: 0.2083
# Parâmetros: ('Skip-gram', 3, 20, 5, True, 5, 3), Distância média: 0.2301
# Parâmetros: ('Skip-gram', 3, 20, 5, False, 2, 3), Distância média: 0.3340
# Parâmetros: ('Skip-gram', 3, 20, 5, False, 3, 3), Distância média: 0.3340
# Parâmetros: ('Skip-gram', 3, 20, 5, False, 5, 3), Distância média: 0.3340
# Treinando modelo com parâmetros: ('Skip-gram', 3, 20, 7, 3)
# Parâmetros: ('Skip-gram', 3, 20, 7, True, 2, 3), Distância média: 0.2805
# Parâmetros: ('Skip-gram', 3, 20, 7, True, 3, 3), Distância média: 0.2922
# Parâmetros: ('Skip-gram', 3, 20, 7, True, 5, 3), Distância média: 0.3108
# Parâmetros: ('Skip-gram', 3, 20, 7, False, 2, 3), Distância média: 0.4033
# Parâmetros: ('Skip-gram', 3, 20, 7, False, 3, 3), Distância média: 0.4033
# Parâmetros: ('Skip-gram', 3, 20, 7, False, 5, 3), Distância média: 0.4033
# Treinando modelo com parâmetros: ('Skip-gram', 3, 20, 10, 3)
# Parâmetros: ('Skip-gram', 3, 20, 10, True, 2, 3), Distância média: 0.4117
# Parâmetros: ('Skip-gram', 3, 20, 10, True, 3, 3), Distância média: 0.4217
# Parâmetros: ('Skip-gram', 3, 20, 10, True, 5, 3), Distância média: 0.4377
# Parâmetros: ('Skip-gram', 3, 20, 10, False, 2, 3), Distância média: 0.5192
# Parâmetros: ('Skip-gram', 3, 20, 10, False, 3, 3), Distância média: 0.5192
# Parâmetros: ('Skip-gram', 3, 20, 10, False, 5, 3), Distância média: 0.5192
# Treinando modelo com parâmetros: ('Skip-gram', 3, 25, 3, 3)
# Parâmetros: ('Skip-gram', 3, 25, 3, True, 2, 3), Distância média: 0.0914
# Parâmetros: ('Skip-gram', 3, 25, 3, True, 3, 3), Distância média: 0.1065
# Parâmetros: ('Skip-gram', 3, 25, 3, True, 5, 3), Distância média: 0.1286
# Parâmetros: ('Skip-gram', 3, 25, 3, False, 2, 3), Distância média: 0.2494
# Parâmetros: ('Skip-gram', 3, 25, 3, False, 3, 3), Distância média: 0.2494
# Parâmetros: ('Skip-gram', 3, 25, 3, False, 5, 3), Distância média: 0.2494
# Treinando modelo com parâmetros: ('Skip-gram', 3, 25, 5, 3)
# Parâmetros: ('Skip-gram', 3, 25, 5, True, 2, 3), Distância média: 0.1699
# Parâmetros: ('Skip-gram', 3, 25, 5, True, 3, 3), Distância média: 0.1811
# Parâmetros: ('Skip-gram', 3, 25, 5, True, 5, 3), Distância média: 0.1989
# Parâmetros: ('Skip-gram', 3, 25, 5, False, 2, 3), Distância média: 0.3031
# Parâmetros: ('Skip-gram', 3, 25, 5, False, 3, 3), Distância média: 0.3031
# Parâmetros: ('Skip-gram', 3, 25, 5, False, 5, 3), Distância média: 0.3031
# Treinando modelo com parâmetros: ('Skip-gram', 3, 25, 7, 3)
# Parâmetros: ('Skip-gram', 3, 25, 7, True, 2, 3), Distância média: 0.2572
# Parâmetros: ('Skip-gram', 3, 25, 7, True, 3, 3), Distância média: 0.2664
# Parâmetros: ('Skip-gram', 3, 25, 7, True, 5, 3), Distância média: 0.2817
# Parâmetros: ('Skip-gram', 3, 25, 7, False, 2, 3), Distância média: 0.3731
# Parâmetros: ('Skip-gram', 3, 25, 7, False, 3, 3), Distância média: 0.3731
# Parâmetros: ('Skip-gram', 3, 25, 7, False, 5, 3), Distância média: 0.3731
# Treinando modelo com parâmetros: ('Skip-gram', 3, 25, 10, 3)
# Parâmetros: ('Skip-gram', 3, 25, 10, True, 2, 3), Distância média: 0.3898
# Parâmetros: ('Skip-gram', 3, 25, 10, True, 3, 3), Distância média: 0.3986
# Parâmetros: ('Skip-gram', 3, 25, 10, True, 5, 3), Distância média: 0.4109
# Parâmetros: ('Skip-gram', 3, 25, 10, False, 2, 3), Distância média: 0.4912
# Parâmetros: ('Skip-gram', 3, 25, 10, False, 3, 3), Distância média: 0.4912
# Parâmetros: ('Skip-gram', 3, 25, 10, False, 5, 3), Distância média: 0.4912
# Treinando modelo com parâmetros: ('Skip-gram', 3, 50, 3, 3)
# Parâmetros: ('Skip-gram', 3, 50, 3, True, 2, 3), Distância média: 0.0701
# Parâmetros: ('Skip-gram', 3, 50, 3, True, 3, 3), Distância média: 0.0762
# Parâmetros: ('Skip-gram', 3, 50, 3, True, 5, 3), Distância média: 0.0857
# Parâmetros: ('Skip-gram', 3, 50, 3, False, 2, 3), Distância média: 0.1852
# Parâmetros: ('Skip-gram', 3, 50, 3, False, 3, 3), Distância média: 0.1852
# Parâmetros: ('Skip-gram', 3, 50, 3, False, 5, 3), Distância média: 0.1852
# Treinando modelo com parâmetros: ('Skip-gram', 3, 50, 5, 3)
# Parâmetros: ('Skip-gram', 3, 50, 5, True, 2, 3), Distância média: 0.1527
# Parâmetros: ('Skip-gram', 3, 50, 5, True, 3, 3), Distância média: 0.1571
# Parâmetros: ('Skip-gram', 3, 50, 5, True, 5, 3), Distância média: 0.1641
# Parâmetros: ('Skip-gram', 3, 50, 5, False, 2, 3), Distância média: 0.2450
# Parâmetros: ('Skip-gram', 3, 50, 5, False, 3, 3), Distância média: 0.2450
# Parâmetros: ('Skip-gram', 3, 50, 5, False, 5, 3), Distância média: 0.2450
# Treinando modelo com parâmetros: ('Skip-gram', 3, 50, 7, 3)
# Parâmetros: ('Skip-gram', 3, 50, 7, True, 2, 3), Distância média: 0.2418
# Parâmetros: ('Skip-gram', 3, 50, 7, True, 3, 3), Distância média: 0.2457
# Parâmetros: ('Skip-gram', 3, 50, 7, True, 5, 3), Distância média: 0.2516
# Parâmetros: ('Skip-gram', 3, 50, 7, False, 2, 3), Distância média: 0.3207
# Parâmetros: ('Skip-gram', 3, 50, 7, False, 3, 3), Distância média: 0.3207
# Parâmetros: ('Skip-gram', 3, 50, 7, False, 5, 3), Distância média: 0.3207
# Treinando modelo com parâmetros: ('Skip-gram', 3, 50, 10, 3)
# Parâmetros: ('Skip-gram', 3, 50, 10, True, 2, 3), Distância média: 0.3765
# Parâmetros: ('Skip-gram', 3, 50, 10, True, 3, 3), Distância média: 0.3798
# Parâmetros: ('Skip-gram', 3, 50, 10, True, 5, 3), Distância média: 0.3853
# Parâmetros: ('Skip-gram', 3, 50, 10, False, 2, 3), Distância média: 0.4445
# Parâmetros: ('Skip-gram', 3, 50, 10, False, 3, 3), Distância média: 0.4445
# Parâmetros: ('Skip-gram', 3, 50, 10, False, 5, 3), Distância média: 0.4445
# Treinando modelo com parâmetros: ('Skip-gram', 3, 100, 3, 3)
# Parâmetros: ('Skip-gram', 3, 100, 3, True, 2, 3), Distância média: 0.0511
# Parâmetros: ('Skip-gram', 3, 100, 3, True, 3, 3), Distância média: 0.0542
# Parâmetros: ('Skip-gram', 3, 100, 3, True, 5, 3), Distância média: 0.0585
# Parâmetros: ('Skip-gram', 3, 100, 3, False, 2, 3), Distância média: 0.1344
# Parâmetros: ('Skip-gram', 3, 100, 3, False, 3, 3), Distância média: 0.1344
# Parâmetros: ('Skip-gram', 3, 100, 3, False, 5, 3), Distância média: 0.1344
# Treinando modelo com parâmetros: ('Skip-gram', 3, 100, 5, 3)
# Parâmetros: ('Skip-gram', 3, 100, 5, True, 2, 3), Distância média: 0.1343
# Parâmetros: ('Skip-gram', 3, 100, 5, True, 3, 3), Distância média: 0.1364
# Parâmetros: ('Skip-gram', 3, 100, 5, True, 5, 3), Distância média: 0.1395
# Parâmetros: ('Skip-gram', 3, 100, 5, False, 2, 3), Distância média: 0.1979
# Parâmetros: ('Skip-gram', 3, 100, 5, False, 3, 3), Distância média: 0.1979
# Parâmetros: ('Skip-gram', 3, 100, 5, False, 5, 3), Distância média: 0.1979
# Treinando modelo com parâmetros: ('Skip-gram', 3, 100, 7, 3)
# Parâmetros: ('Skip-gram', 3, 100, 7, True, 2, 3), Distância média: 0.2238
# Parâmetros: ('Skip-gram', 3, 100, 7, True, 3, 3), Distância média: 0.2256
# Parâmetros: ('Skip-gram', 3, 100, 7, True, 5, 3), Distância média: 0.2283
# Parâmetros: ('Skip-gram', 3, 100, 7, False, 2, 3), Distância média: 0.2773
# Parâmetros: ('Skip-gram', 3, 100, 7, False, 3, 3), Distância média: 0.2773
# Parâmetros: ('Skip-gram', 3, 100, 7, False, 5, 3), Distância média: 0.2773
# Treinando modelo com parâmetros: ('Skip-gram', 3, 100, 10, 3)
# Parâmetros: ('Skip-gram', 3, 100, 10, True, 2, 3), Distância média: 0.3583
# Parâmetros: ('Skip-gram', 3, 100, 10, True, 3, 3), Distância média: 0.3598
# Parâmetros: ('Skip-gram', 3, 100, 10, True, 5, 3), Distância média: 0.3625
# Parâmetros: ('Skip-gram', 3, 100, 10, False, 2, 3), Distância média: 0.4057
# Parâmetros: ('Skip-gram', 3, 100, 10, False, 3, 3), Distância média: 0.4057
# Parâmetros: ('Skip-gram', 3, 100, 10, False, 5, 3), Distância média: 0.4057
# Treinando modelo com parâmetros: ('Skip-gram', 4, 5, 3, 3)
# Parâmetros: ('Skip-gram', 4, 5, 3, True, 2, 3), Distância média: 0.3397
# Parâmetros: ('Skip-gram', 4, 5, 3, True, 3, 3), Distância média: 0.4152
# Parâmetros: ('Skip-gram', 4, 5, 3, True, 5, 3), Distância média: 0.5320
# Parâmetros: ('Skip-gram', 4, 5, 3, False, 2, 3), Distância média: 0.5320
# Parâmetros: ('Skip-gram', 4, 5, 3, False, 3, 3), Distância média: 0.5320
# Parâmetros: ('Skip-gram', 4, 5, 3, False, 5, 3), Distância média: 0.5320
# Treinando modelo com parâmetros: ('Skip-gram', 4, 5, 5, 3)
# Parâmetros: ('Skip-gram', 4, 5, 5, True, 2, 3), Distância média: 0.4246
# Parâmetros: ('Skip-gram', 4, 5, 5, True, 3, 3), Distância média: 0.4926
# Parâmetros: ('Skip-gram', 4, 5, 5, True, 5, 3), Distância média: 0.6003
# Parâmetros: ('Skip-gram', 4, 5, 5, False, 2, 3), Distância média: 0.6003
# Parâmetros: ('Skip-gram', 4, 5, 5, False, 3, 3), Distância média: 0.6003
# Parâmetros: ('Skip-gram', 4, 5, 5, False, 5, 3), Distância média: 0.6003
# Treinando modelo com parâmetros: ('Skip-gram', 4, 5, 7, 3)
# Parâmetros: ('Skip-gram', 4, 5, 7, True, 2, 3), Distância média: 0.5210
# Parâmetros: ('Skip-gram', 4, 5, 7, True, 3, 3), Distância média: 0.5826
# Parâmetros: ('Skip-gram', 4, 5, 7, True, 5, 3), Distância média: 0.6825
# Parâmetros: ('Skip-gram', 4, 5, 7, False, 2, 3), Distância média: 0.6825
# Parâmetros: ('Skip-gram', 4, 5, 7, False, 3, 3), Distância média: 0.6825
# Parâmetros: ('Skip-gram', 4, 5, 7, False, 5, 3), Distância média: 0.6825
# Treinando modelo com parâmetros: ('Skip-gram', 4, 5, 10, 3)
# Parâmetros: ('Skip-gram', 4, 5, 10, True, 2, 3), Distância média: 0.6662
# Parâmetros: ('Skip-gram', 4, 5, 10, True, 3, 3), Distância média: 0.7206
# Parâmetros: ('Skip-gram', 4, 5, 10, True, 5, 3), Distância média: 0.8127
# Parâmetros: ('Skip-gram', 4, 5, 10, False, 2, 3), Distância média: 0.8127
# Parâmetros: ('Skip-gram', 4, 5, 10, False, 3, 3), Distância média: 0.8127
# Parâmetros: ('Skip-gram', 4, 5, 10, False, 5, 3), Distância média: 0.8127
# Treinando modelo com parâmetros: ('Skip-gram', 4, 20, 3, 3)
# Parâmetros: ('Skip-gram', 4, 20, 3, True, 2, 3), Distância média: 0.1615
# Parâmetros: ('Skip-gram', 4, 20, 3, True, 3, 3), Distância média: 0.1763
# Parâmetros: ('Skip-gram', 4, 20, 3, True, 5, 3), Distância média: 0.1996
# Parâmetros: ('Skip-gram', 4, 20, 3, False, 2, 3), Distância média: 0.3089
# Parâmetros: ('Skip-gram', 4, 20, 3, False, 3, 3), Distância média: 0.3089
# Parâmetros: ('Skip-gram', 4, 20, 3, False, 5, 3), Distância média: 0.3089
# Treinando modelo com parâmetros: ('Skip-gram', 4, 20, 5, 3)
# Parâmetros: ('Skip-gram', 4, 20, 5, True, 2, 3), Distância média: 0.2706
# Parâmetros: ('Skip-gram', 4, 20, 5, True, 3, 3), Distância média: 0.2822
# Parâmetros: ('Skip-gram', 4, 20, 5, True, 5, 3), Distância média: 0.3010
# Parâmetros: ('Skip-gram', 4, 20, 5, False, 2, 3), Distância média: 0.3940
# Parâmetros: ('Skip-gram', 4, 20, 5, False, 3, 3), Distância média: 0.3940
# Parâmetros: ('Skip-gram', 4, 20, 5, False, 5, 3), Distância média: 0.3940
# Treinando modelo com parâmetros: ('Skip-gram', 4, 20, 7, 3)
# Parâmetros: ('Skip-gram', 4, 20, 7, True, 2, 3), Distância média: 0.3820
# Parâmetros: ('Skip-gram', 4, 20, 7, True, 3, 3), Distância média: 0.3921
# Parâmetros: ('Skip-gram', 4, 20, 7, True, 5, 3), Distância média: 0.4085
# Parâmetros: ('Skip-gram', 4, 20, 7, False, 2, 3), Distância média: 0.4912
# Parâmetros: ('Skip-gram', 4, 20, 7, False, 3, 3), Distância média: 0.4912
# Parâmetros: ('Skip-gram', 4, 20, 7, False, 5, 3), Distância média: 0.4912
# Treinando modelo com parâmetros: ('Skip-gram', 4, 20, 10, 3)
# Parâmetros: ('Skip-gram', 4, 20, 10, True, 2, 3), Distância média: 0.5418
# Parâmetros: ('Skip-gram', 4, 20, 10, True, 3, 3), Distância média: 0.5505
# Parâmetros: ('Skip-gram', 4, 20, 10, True, 5, 3), Distância média: 0.5650
# Parâmetros: ('Skip-gram', 4, 20, 10, False, 2, 3), Distância média: 0.6393
# Parâmetros: ('Skip-gram', 4, 20, 10, False, 3, 3), Distância média: 0.6393
# Parâmetros: ('Skip-gram', 4, 20, 10, False, 5, 3), Distância média: 0.6393
# Treinando modelo com parâmetros: ('Skip-gram', 4, 25, 3, 3)
# Parâmetros: ('Skip-gram', 4, 25, 3, True, 2, 3), Distância média: 0.1371
# Parâmetros: ('Skip-gram', 4, 25, 3, True, 3, 3), Distância média: 0.1496
# Parâmetros: ('Skip-gram', 4, 25, 3, True, 5, 3), Distância média: 0.1691
# Parâmetros: ('Skip-gram', 4, 25, 3, False, 2, 3), Distância média: 0.2790
# Parâmetros: ('Skip-gram', 4, 25, 3, False, 3, 3), Distância média: 0.2790
# Parâmetros: ('Skip-gram', 4, 25, 3, False, 5, 3), Distância média: 0.2790
# Treinando modelo com parâmetros: ('Skip-gram', 4, 25, 5, 3)
# Parâmetros: ('Skip-gram', 4, 25, 5, True, 2, 3), Distância média: 0.2471
# Parâmetros: ('Skip-gram', 4, 25, 5, True, 3, 3), Distância média: 0.2565
# Parâmetros: ('Skip-gram', 4, 25, 5, True, 5, 3), Distância média: 0.2721
# Parâmetros: ('Skip-gram', 4, 25, 5, False, 2, 3), Distância média: 0.3643
# Parâmetros: ('Skip-gram', 4, 25, 5, False, 3, 3), Distância média: 0.3643
# Parâmetros: ('Skip-gram', 4, 25, 5, False, 5, 3), Distância média: 0.3643
# Treinando modelo com parâmetros: ('Skip-gram', 4, 25, 7, 3)
# Parâmetros: ('Skip-gram', 4, 25, 7, True, 2, 3), Distância média: 0.3592
# Parâmetros: ('Skip-gram', 4, 25, 7, True, 3, 3), Distância média: 0.3674
# Parâmetros: ('Skip-gram', 4, 25, 7, True, 5, 3), Distância média: 0.3811
# Parâmetros: ('Skip-gram', 4, 25, 7, False, 2, 3), Distância média: 0.4627
# Parâmetros: ('Skip-gram', 4, 25, 7, False, 3, 3), Distância média: 0.4627
# Parâmetros: ('Skip-gram', 4, 25, 7, False, 5, 3), Distância média: 0.4627
# Treinando modelo com parâmetros: ('Skip-gram', 4, 25, 10, 3)
# Parâmetros: ('Skip-gram', 4, 25, 10, True, 2, 3), Distância média: 0.5208
# Parâmetros: ('Skip-gram', 4, 25, 10, True, 3, 3), Distância média: 0.5280
# Parâmetros: ('Skip-gram', 4, 25, 10, True, 5, 3), Distância média: 0.5403
# Parâmetros: ('Skip-gram', 4, 25, 10, False, 2, 3), Distância média: 0.6134
# Parâmetros: ('Skip-gram', 4, 25, 10, False, 3, 3), Distância média: 0.6134
# Parâmetros: ('Skip-gram', 4, 25, 10, False, 5, 3), Distância média: 0.6134
# Treinando modelo com parâmetros: ('Skip-gram', 4, 50, 3, 3)
# Parâmetros: ('Skip-gram', 4, 50, 3, True, 2, 3), Distância média: 0.1162
# Parâmetros: ('Skip-gram', 4, 50, 3, True, 3, 3), Distância média: 0.1212
# Parâmetros: ('Skip-gram', 4, 50, 3, True, 5, 3), Distância média: 0.1289
# Parâmetros: ('Skip-gram', 4, 50, 3, False, 2, 3), Distância média: 0.2165
# Parâmetros: ('Skip-gram', 4, 50, 3, False, 3, 3), Distância média: 0.2165
# Parâmetros: ('Skip-gram', 4, 50, 3, False, 5, 3), Distância média: 0.2165
# Treinando modelo com parâmetros: ('Skip-gram', 4, 50, 5, 3)
# Parâmetros: ('Skip-gram', 4, 50, 5, True, 2, 3), Distância média: 0.2298
# Parâmetros: ('Skip-gram', 4, 50, 5, True, 3, 3), Distância média: 0.2337
# Parâmetros: ('Skip-gram', 4, 50, 5, True, 5, 3), Distância média: 0.2396
# Parâmetros: ('Skip-gram', 4, 50, 5, False, 2, 3), Distância média: 0.3096
# Parâmetros: ('Skip-gram', 4, 50, 5, False, 3, 3), Distância média: 0.3096
# Parâmetros: ('Skip-gram', 4, 50, 5, False, 5, 3), Distância média: 0.3096
# Treinando modelo com parâmetros: ('Skip-gram', 4, 50, 7, 3)
# Parâmetros: ('Skip-gram', 4, 50, 7, True, 2, 3), Distância média: 0.3436
# Parâmetros: ('Skip-gram', 4, 50, 7, True, 3, 3), Distância média: 0.3470
# Parâmetros: ('Skip-gram', 4, 50, 7, True, 5, 3), Distância média: 0.3525
# Parâmetros: ('Skip-gram', 4, 50, 7, False, 2, 3), Distância média: 0.4134
# Parâmetros: ('Skip-gram', 4, 50, 7, False, 3, 3), Distância média: 0.4134
# Parâmetros: ('Skip-gram', 4, 50, 7, False, 5, 3), Distância média: 0.4134
# Treinando modelo com parâmetros: ('Skip-gram', 4, 50, 10, 3)
# Parâmetros: ('Skip-gram', 4, 50, 10, True, 2, 3), Distância média: 0.5062
# Parâmetros: ('Skip-gram', 4, 50, 10, True, 3, 3), Distância média: 0.5098
# Parâmetros: ('Skip-gram', 4, 50, 10, True, 5, 3), Distância média: 0.5146
# Parâmetros: ('Skip-gram', 4, 50, 10, False, 2, 3), Distância média: 0.5691
# Parâmetros: ('Skip-gram', 4, 50, 10, False, 3, 3), Distância média: 0.5691
# Parâmetros: ('Skip-gram', 4, 50, 10, False, 5, 3), Distância média: 0.5691
# Treinando modelo com parâmetros: ('Skip-gram', 4, 100, 3, 3)
# Parâmetros: ('Skip-gram', 4, 100, 3, True, 2, 3), Distância média: 0.0989
# Parâmetros: ('Skip-gram', 4, 100, 3, True, 3, 3), Distância média: 0.1012
# Parâmetros: ('Skip-gram', 4, 100, 3, True, 5, 3), Distância média: 0.1046
# Parâmetros: ('Skip-gram', 4, 100, 3, False, 2, 3), Distância média: 0.1685
# Parâmetros: ('Skip-gram', 4, 100, 3, False, 3, 3), Distância média: 0.1685
# Parâmetros: ('Skip-gram', 4, 100, 3, False, 5, 3), Distância média: 0.1685
# Treinando modelo com parâmetros: ('Skip-gram', 4, 100, 5, 3)
# Parâmetros: ('Skip-gram', 4, 100, 5, True, 2, 3), Distância média: 0.2143
# Parâmetros: ('Skip-gram', 4, 100, 5, True, 3, 3), Distância média: 0.2161
# Parâmetros: ('Skip-gram', 4, 100, 5, True, 5, 3), Distância média: 0.2188
# Parâmetros: ('Skip-gram', 4, 100, 5, False, 2, 3), Distância média: 0.2682
# Parâmetros: ('Skip-gram', 4, 100, 5, False, 3, 3), Distância média: 0.2682
# Parâmetros: ('Skip-gram', 4, 100, 5, False, 5, 3), Distância média: 0.2682
# Treinando modelo com parâmetros: ('Skip-gram', 4, 100, 7, 3)
# Parâmetros: ('Skip-gram', 4, 100, 7, True, 2, 3), Distância média: 0.3283
# Parâmetros: ('Skip-gram', 4, 100, 7, True, 3, 3), Distância média: 0.3300
# Parâmetros: ('Skip-gram', 4, 100, 7, True, 5, 3), Distância média: 0.3324
# Parâmetros: ('Skip-gram', 4, 100, 7, False, 2, 3), Distância média: 0.3759
# Parâmetros: ('Skip-gram', 4, 100, 7, False, 3, 3), Distância média: 0.3759
# Parâmetros: ('Skip-gram', 4, 100, 7, False, 5, 3), Distância média: 0.3759
# Treinando modelo com parâmetros: ('Skip-gram', 4, 100, 10, 3)
# Parâmetros: ('Skip-gram', 4, 100, 10, True, 2, 3), Distância média: 0.4917
# Parâmetros: ('Skip-gram', 4, 100, 10, True, 3, 3), Distância média: 0.4931
# Parâmetros: ('Skip-gram', 4, 100, 10, True, 5, 3), Distância média: 0.4957
# Parâmetros: ('Skip-gram', 4, 100, 10, False, 2, 3), Distância média: 0.5356
# Parâmetros: ('Skip-gram', 4, 100, 10, False, 3, 3), Distância média: 0.5356
# Parâmetros: ('Skip-gram', 4, 100, 10, False, 5, 3), Distância média: 0.5356
# Treinando modelo com parâmetros: ('Skip-gram', 5, 5, 3, 3)
# Parâmetros: ('Skip-gram', 5, 5, 3, True, 2, 3), Distância média: 0.3674
# Parâmetros: ('Skip-gram', 5, 5, 3, True, 3, 3), Distância média: 0.4398
# Parâmetros: ('Skip-gram', 5, 5, 3, True, 5, 3), Distância média: 0.5518
# Parâmetros: ('Skip-gram', 5, 5, 3, False, 2, 3), Distância média: 0.5518
# Parâmetros: ('Skip-gram', 5, 5, 3, False, 3, 3), Distância média: 0.5518
# Parâmetros: ('Skip-gram', 5, 5, 3, False, 5, 3), Distância média: 0.5518
# Treinando modelo com parâmetros: ('Skip-gram', 5, 5, 5, 3)
# Parâmetros: ('Skip-gram', 5, 5, 5, True, 2, 3), Distância média: 0.4753
# Parâmetros: ('Skip-gram', 5, 5, 5, True, 3, 3), Distância média: 0.5392
# Parâmetros: ('Skip-gram', 5, 5, 5, True, 5, 3), Distância média: 0.6413
# Parâmetros: ('Skip-gram', 5, 5, 5, False, 2, 3), Distância média: 0.6413
# Parâmetros: ('Skip-gram', 5, 5, 5, False, 3, 3), Distância média: 0.6413
# Parâmetros: ('Skip-gram', 5, 5, 5, False, 5, 3), Distância média: 0.6413
# Treinando modelo com parâmetros: ('Skip-gram', 5, 5, 7, 3)
# Parâmetros: ('Skip-gram', 5, 5, 7, True, 2, 3), Distância média: 0.5906
# Parâmetros: ('Skip-gram', 5, 5, 7, True, 3, 3), Distância média: 0.6478
# Parâmetros: ('Skip-gram', 5, 5, 7, True, 5, 3), Distância média: 0.7420
# Parâmetros: ('Skip-gram', 5, 5, 7, False, 2, 3), Distância média: 0.7420
# Parâmetros: ('Skip-gram', 5, 5, 7, False, 3, 3), Distância média: 0.7420
# Parâmetros: ('Skip-gram', 5, 5, 7, False, 5, 3), Distância média: 0.7420
# Treinando modelo com parâmetros: ('Skip-gram', 5, 5, 10, 3)
# Parâmetros: ('Skip-gram', 5, 5, 10, True, 2, 3), Distância média: 0.7535
# Parâmetros: ('Skip-gram', 5, 5, 10, True, 3, 3), Distância média: 0.8055
# Parâmetros: ('Skip-gram', 5, 5, 10, True, 5, 3), Distância média: 0.8924
# Parâmetros: ('Skip-gram', 5, 5, 10, False, 2, 3), Distância média: 0.8924
# Parâmetros: ('Skip-gram', 5, 5, 10, False, 3, 3), Distância média: 0.8924
# Parâmetros: ('Skip-gram', 5, 5, 10, False, 5, 3), Distância média: 0.8924
# Treinando modelo com parâmetros: ('Skip-gram', 5, 20, 3, 3)
# Parâmetros: ('Skip-gram', 5, 20, 3, True, 2, 3), Distância média: 0.1968
# Parâmetros: ('Skip-gram', 5, 20, 3, True, 3, 3), Distância média: 0.2102
# Parâmetros: ('Skip-gram', 5, 20, 3, True, 5, 3), Distância média: 0.2318
# Parâmetros: ('Skip-gram', 5, 20, 3, False, 2, 3), Distância média: 0.3350
# Parâmetros: ('Skip-gram', 5, 20, 3, False, 3, 3), Distância média: 0.3350
# Parâmetros: ('Skip-gram', 5, 20, 3, False, 5, 3), Distância média: 0.3350
# Treinando modelo com parâmetros: ('Skip-gram', 5, 20, 5, 3)
# Parâmetros: ('Skip-gram', 5, 20, 5, True, 2, 3), Distância média: 0.3296
# Parâmetros: ('Skip-gram', 5, 20, 5, True, 3, 3), Distância média: 0.3403
# Parâmetros: ('Skip-gram', 5, 20, 5, True, 5, 3), Distância média: 0.3578
# Parâmetros: ('Skip-gram', 5, 20, 5, False, 2, 3), Distância média: 0.4447
# Parâmetros: ('Skip-gram', 5, 20, 5, False, 3, 3), Distância média: 0.4447
# Parâmetros: ('Skip-gram', 5, 20, 5, False, 5, 3), Distância média: 0.4447
# Treinando modelo com parâmetros: ('Skip-gram', 5, 20, 7, 3)
# Parâmetros: ('Skip-gram', 5, 20, 7, True, 2, 3), Distância média: 0.4590
# Parâmetros: ('Skip-gram', 5, 20, 7, True, 3, 3), Distância média: 0.4684
# Parâmetros: ('Skip-gram', 5, 20, 7, True, 5, 3), Distância média: 0.4837
# Parâmetros: ('Skip-gram', 5, 20, 7, False, 2, 3), Distância média: 0.5617
# Parâmetros: ('Skip-gram', 5, 20, 7, False, 3, 3), Distância média: 0.5617
# Parâmetros: ('Skip-gram', 5, 20, 7, False, 5, 3), Distância média: 0.5617
# Treinando modelo com parâmetros: ('Skip-gram', 5, 20, 10, 3)
# Parâmetros: ('Skip-gram', 5, 20, 10, True, 2, 3), Distância média: 0.6370
# Parâmetros: ('Skip-gram', 5, 20, 10, True, 3, 3), Distância média: 0.6448
# Parâmetros: ('Skip-gram', 5, 20, 10, True, 5, 3), Distância média: 0.6590
# Parâmetros: ('Skip-gram', 5, 20, 10, False, 2, 3), Distância média: 0.7299
# Parâmetros: ('Skip-gram', 5, 20, 10, False, 3, 3), Distância média: 0.7299
# Parâmetros: ('Skip-gram', 5, 20, 10, False, 5, 3), Distância média: 0.7299
# Treinando modelo com parâmetros: ('Skip-gram', 5, 25, 3, 3)
# Parâmetros: ('Skip-gram', 5, 25, 3, True, 2, 3), Distância média: 0.1743
# Parâmetros: ('Skip-gram', 5, 25, 3, True, 3, 3), Distância média: 0.1844
# Parâmetros: ('Skip-gram', 5, 25, 3, True, 5, 3), Distância média: 0.2019
# Parâmetros: ('Skip-gram', 5, 25, 3, False, 2, 3), Distância média: 0.3050
# Parâmetros: ('Skip-gram', 5, 25, 3, False, 3, 3), Distância média: 0.3050
# Parâmetros: ('Skip-gram', 5, 25, 3, False, 5, 3), Distância média: 0.3050
# Treinando modelo com parâmetros: ('Skip-gram', 5, 25, 5, 3)
# Parâmetros: ('Skip-gram', 5, 25, 5, True, 2, 3), Distância média: 0.3080
# Parâmetros: ('Skip-gram', 5, 25, 5, True, 3, 3), Distância média: 0.3165
# Parâmetros: ('Skip-gram', 5, 25, 5, True, 5, 3), Distância média: 0.3308
# Parâmetros: ('Skip-gram', 5, 25, 5, False, 2, 3), Distância média: 0.4163
# Parâmetros: ('Skip-gram', 5, 25, 5, False, 3, 3), Distância média: 0.4163
# Parâmetros: ('Skip-gram', 5, 25, 5, False, 5, 3), Distância média: 0.4163
# Treinando modelo com parâmetros: ('Skip-gram', 5, 25, 7, 3)
# Parâmetros: ('Skip-gram', 5, 25, 7, True, 2, 3), Distância média: 0.4388
# Parâmetros: ('Skip-gram', 5, 25, 7, True, 3, 3), Distância média: 0.4463
# Parâmetros: ('Skip-gram', 5, 25, 7, True, 5, 3), Distância média: 0.4590
# Parâmetros: ('Skip-gram', 5, 25, 7, False, 2, 3), Distância média: 0.5355
# Parâmetros: ('Skip-gram', 5, 25, 7, False, 3, 3), Distância média: 0.5355
# Parâmetros: ('Skip-gram', 5, 25, 7, False, 5, 3), Distância média: 0.5355
# Treinando modelo com parâmetros: ('Skip-gram', 5, 25, 10, 3)
# Parâmetros: ('Skip-gram', 5, 25, 10, True, 2, 3), Distância média: 0.6185
# Parâmetros: ('Skip-gram', 5, 25, 10, True, 3, 3), Distância média: 0.6252
# Parâmetros: ('Skip-gram', 5, 25, 10, True, 5, 3), Distância média: 0.6374
# Parâmetros: ('Skip-gram', 5, 25, 10, False, 2, 3), Distância média: 0.7067
# Parâmetros: ('Skip-gram', 5, 25, 10, False, 3, 3), Distância média: 0.7067
# Parâmetros: ('Skip-gram', 5, 25, 10, False, 5, 3), Distância média: 0.7067
# Treinando modelo com parâmetros: ('Skip-gram', 5, 50, 3, 3)
# Parâmetros: ('Skip-gram', 5, 50, 3, True, 2, 3), Distância média: 0.1556
# Parâmetros: ('Skip-gram', 5, 50, 3, True, 3, 3), Distância média: 0.1600
# Parâmetros: ('Skip-gram', 5, 50, 3, True, 5, 3), Distância média: 0.1668
# Parâmetros: ('Skip-gram', 5, 50, 3, False, 2, 3), Distância média: 0.2469
# Parâmetros: ('Skip-gram', 5, 50, 3, False, 3, 3), Distância média: 0.2469
# Parâmetros: ('Skip-gram', 5, 50, 3, False, 5, 3), Distância média: 0.2469
# Treinando modelo com parâmetros: ('Skip-gram', 5, 50, 5, 3)
# Parâmetros: ('Skip-gram', 5, 50, 5, True, 2, 3), Distância média: 0.2924
# Parâmetros: ('Skip-gram', 5, 50, 5, True, 3, 3), Distância média: 0.2960
# Parâmetros: ('Skip-gram', 5, 50, 5, True, 5, 3), Distância média: 0.3014
# Parâmetros: ('Skip-gram', 5, 50, 5, False, 2, 3), Distância média: 0.3661
# Parâmetros: ('Skip-gram', 5, 50, 5, False, 3, 3), Distância média: 0.3661
# Parâmetros: ('Skip-gram', 5, 50, 5, False, 5, 3), Distância média: 0.3661
# Treinando modelo com parâmetros: ('Skip-gram', 5, 50, 7, 3)
# Parâmetros: ('Skip-gram', 5, 50, 7, True, 2, 3), Distância média: 0.4242
# Parâmetros: ('Skip-gram', 5, 50, 7, True, 3, 3), Distância média: 0.4274
# Parâmetros: ('Skip-gram', 5, 50, 7, True, 5, 3), Distância média: 0.4326
# Parâmetros: ('Skip-gram', 5, 50, 7, False, 2, 3), Distância média: 0.4901
# Parâmetros: ('Skip-gram', 5, 50, 7, False, 3, 3), Distância média: 0.4901
# Parâmetros: ('Skip-gram', 5, 50, 7, False, 5, 3), Distância média: 0.4901
# Treinando modelo com parâmetros: ('Skip-gram', 5, 50, 10, 3)
# Parâmetros: ('Skip-gram', 5, 50, 10, True, 2, 3), Distância média: 0.6047
# Parâmetros: ('Skip-gram', 5, 50, 10, True, 3, 3), Distância média: 0.6084
# Parâmetros: ('Skip-gram', 5, 50, 10, True, 5, 3), Distância média: 0.6131
# Parâmetros: ('Skip-gram', 5, 50, 10, False, 2, 3), Distância média: 0.6653
# Parâmetros: ('Skip-gram', 5, 50, 10, False, 3, 3), Distância média: 0.6653
# Parâmetros: ('Skip-gram', 5, 50, 10, False, 5, 3), Distância média: 0.6653
# Treinando modelo com parâmetros: ('Skip-gram', 5, 100, 3, 3)
# Parâmetros: ('Skip-gram', 5, 100, 3, True, 2, 3), Distância média: 0.1399
# Parâmetros: ('Skip-gram', 5, 100, 3, True, 3, 3), Distância média: 0.1420
# Parâmetros: ('Skip-gram', 5, 100, 3, True, 5, 3), Distância média: 0.1450
# Parâmetros: ('Skip-gram', 5, 100, 3, False, 2, 3), Distância média: 0.2025
# Parâmetros: ('Skip-gram', 5, 100, 3, False, 3, 3), Distância média: 0.2025
# Parâmetros: ('Skip-gram', 5, 100, 3, False, 5, 3), Distância média: 0.2025
# Treinando modelo com parâmetros: ('Skip-gram', 5, 100, 5, 3)
# Parâmetros: ('Skip-gram', 5, 100, 5, True, 2, 3), Distância média: 0.2773
# Parâmetros: ('Skip-gram', 5, 100, 5, True, 3, 3), Distância média: 0.2790
# Parâmetros: ('Skip-gram', 5, 100, 5, True, 5, 3), Distância média: 0.2816
# Parâmetros: ('Skip-gram', 5, 100, 5, False, 2, 3), Distância média: 0.3276
# Parâmetros: ('Skip-gram', 5, 100, 5, False, 3, 3), Distância média: 0.3276
# Parâmetros: ('Skip-gram', 5, 100, 5, False, 5, 3), Distância média: 0.3276
# Treinando modelo com parâmetros: ('Skip-gram', 5, 100, 7, 3)
# Parâmetros: ('Skip-gram', 5, 100, 7, True, 2, 3), Distância média: 0.4094
# Parâmetros: ('Skip-gram', 5, 100, 7, True, 3, 3), Distância média: 0.4110
# Parâmetros: ('Skip-gram', 5, 100, 7, True, 5, 3), Distância média: 0.4135
# Parâmetros: ('Skip-gram', 5, 100, 7, False, 2, 3), Distância média: 0.4550
# Parâmetros: ('Skip-gram', 5, 100, 7, False, 3, 3), Distância média: 0.4550
# Parâmetros: ('Skip-gram', 5, 100, 7, False, 5, 3), Distância média: 0.4550
# Treinando modelo com parâmetros: ('Skip-gram', 5, 100, 10, 3)
# Parâmetros: ('Skip-gram', 5, 100, 10, True, 2, 3), Distância média: 0.5918
# Parâmetros: ('Skip-gram', 5, 100, 10, True, 3, 3), Distância média: 0.5931
# Parâmetros: ('Skip-gram', 5, 100, 10, True, 5, 3), Distância média: 0.5955
# Parâmetros: ('Skip-gram', 5, 100, 10, False, 2, 3), Distância média: 0.6341
# Parâmetros: ('Skip-gram', 5, 100, 10, False, 3, 3), Distância média: 0.6341
# Parâmetros: ('Skip-gram', 5, 100, 10, False, 5, 3), Distância média: 0.6341
# Treinando modelo com parâmetros: ('CBOW', 2, 5, 3, 3)
# Parâmetros: ('CBOW', 2, 5, 3, True, 2, 3), Distância média: 0.2865
# Parâmetros: ('CBOW', 2, 5, 3, True, 3, 3), Distância média: 0.3610
# Parâmetros: ('CBOW', 2, 5, 3, True, 5, 3), Distância média: 0.4873
# Parâmetros: ('CBOW', 2, 5, 3, False, 2, 3), Distância média: 0.4873
# Parâmetros: ('CBOW', 2, 5, 3, False, 3, 3), Distância média: 0.4873
# Parâmetros: ('CBOW', 2, 5, 3, False, 5, 3), Distância média: 0.4873
# Treinando modelo com parâmetros: ('CBOW', 2, 5, 5, 3)
# Parâmetros: ('CBOW', 2, 5, 5, True, 2, 3), Distância média: 0.2867
# Parâmetros: ('CBOW', 2, 5, 5, True, 3, 3), Distância média: 0.3686
# Parâmetros: ('CBOW', 2, 5, 5, True, 5, 3), Distância média: 0.4927
# Parâmetros: ('CBOW', 2, 5, 5, False, 2, 3), Distância média: 0.4927
# Parâmetros: ('CBOW', 2, 5, 5, False, 3, 3), Distância média: 0.4927
# Parâmetros: ('CBOW', 2, 5, 5, False, 5, 3), Distância média: 0.4927
# Treinando modelo com parâmetros: ('CBOW', 2, 5, 7, 3)
# Parâmetros: ('CBOW', 2, 5, 7, True, 2, 3), Distância média: 0.3069
# Parâmetros: ('CBOW', 2, 5, 7, True, 3, 3), Distância média: 0.3867
# Parâmetros: ('CBOW', 2, 5, 7, True, 5, 3), Distância média: 0.5078
# Parâmetros: ('CBOW', 2, 5, 7, False, 2, 3), Distância média: 0.5078
# Parâmetros: ('CBOW', 2, 5, 7, False, 3, 3), Distância média: 0.5078
# Parâmetros: ('CBOW', 2, 5, 7, False, 5, 3), Distância média: 0.5078
# Treinando modelo com parâmetros: ('CBOW', 2, 5, 10, 3)
# Parâmetros: ('CBOW', 2, 5, 10, True, 2, 3), Distância média: 0.3498
# Parâmetros: ('CBOW', 2, 5, 10, True, 3, 3), Distância média: 0.4255
# Parâmetros: ('CBOW', 2, 5, 10, True, 5, 3), Distância média: 0.5418
# Parâmetros: ('CBOW', 2, 5, 10, False, 2, 3), Distância média: 0.5418
# Parâmetros: ('CBOW', 2, 5, 10, False, 3, 3), Distância média: 0.5418
# Parâmetros: ('CBOW', 2, 5, 10, False, 5, 3), Distância média: 0.5418
# Treinando modelo com parâmetros: ('CBOW', 2, 20, 3, 3)
# Parâmetros: ('CBOW', 2, 20, 3, True, 2, 3), Distância média: 0.0732
# Parâmetros: ('CBOW', 2, 20, 3, True, 3, 3), Distância média: 0.0926
# Parâmetros: ('CBOW', 2, 20, 3, True, 5, 3), Distância média: 0.1227
# Parâmetros: ('CBOW', 2, 20, 3, False, 2, 3), Distância média: 0.2526
# Parâmetros: ('CBOW', 2, 20, 3, False, 3, 3), Distância média: 0.2526
# Parâmetros: ('CBOW', 2, 20, 3, False, 5, 3), Distância média: 0.2526
# Treinando modelo com parâmetros: ('CBOW', 2, 20, 5, 3)
# Parâmetros: ('CBOW', 2, 20, 5, True, 2, 3), Distância média: 0.0771
# Parâmetros: ('CBOW', 2, 20, 5, True, 3, 3), Distância média: 0.0971
# Parâmetros: ('CBOW', 2, 20, 5, True, 5, 3), Distância média: 0.1273
# Parâmetros: ('CBOW', 2, 20, 5, False, 2, 3), Distância média: 0.2551
# Parâmetros: ('CBOW', 2, 20, 5, False, 3, 3), Distância média: 0.2551
# Parâmetros: ('CBOW', 2, 20, 5, False, 5, 3), Distância média: 0.2551
# Treinando modelo com parâmetros: ('CBOW', 2, 20, 7, 3)
# Parâmetros: ('CBOW', 2, 20, 7, True, 2, 3), Distância média: 0.0979
# Parâmetros: ('CBOW', 2, 20, 7, True, 3, 3), Distância média: 0.1164
# Parâmetros: ('CBOW', 2, 20, 7, True, 5, 3), Distância média: 0.1447
# Parâmetros: ('CBOW', 2, 20, 7, False, 2, 3), Distância média: 0.2675
# Parâmetros: ('CBOW', 2, 20, 7, False, 3, 3), Distância média: 0.2675
# Parâmetros: ('CBOW', 2, 20, 7, False, 5, 3), Distância média: 0.2675
# Treinando modelo com parâmetros: ('CBOW', 2, 20, 10, 3)
# Parâmetros: ('CBOW', 2, 20, 10, True, 2, 3), Distância média: 0.1520
# Parâmetros: ('CBOW', 2, 20, 10, True, 3, 3), Distância média: 0.1681
# Parâmetros: ('CBOW', 2, 20, 10, True, 5, 3), Distância média: 0.1931
# Parâmetros: ('CBOW', 2, 20, 10, False, 2, 3), Distância média: 0.3064
# Parâmetros: ('CBOW', 2, 20, 10, False, 3, 3), Distância média: 0.3064
# Parâmetros: ('CBOW', 2, 20, 10, False, 5, 3), Distância média: 0.3064
# Treinando modelo com parâmetros: ('CBOW', 2, 25, 3, 3)
# Parâmetros: ('CBOW', 2, 25, 3, True, 2, 3), Distância média: 0.0592
# Parâmetros: ('CBOW', 2, 25, 3, True, 3, 3), Distância média: 0.0753
# Parâmetros: ('CBOW', 2, 25, 3, True, 5, 3), Distância média: 0.0998

# %% [markdown]
# ## Resultados

# %% [markdown]
# Após a execução do código, temos os resultados.

# %%
print("Melhores parâmetros encontrados:", best_params)
# Out:
# Melhores parâmetros encontrados: ('CBOW', 2, 100, 3, True, 2, 3)

# %% [markdown]
# E para observar as demais avaliações dos modelos:

# %%
import pandas as pd

# Filtrar as linhas onde PCA não foi aplicado
no_pca = results_df['PCA Aplicado'] == "Não Aplicado"

# Para as linhas onde PCA não foi aplicado, substituir os componentes por "-"
results_df.loc[no_pca, 'Componentes PCA'] = "-"

# Remover duplicatas considerando todas as colunas (com os "-" já ajustados)
results_df = results_df.drop_duplicates()

# %%
results_df = results_df.sort_values(by=["Distância Média"])

# %%
print("Melhores resultados detalhados:")
results_df.head(15)
# Out:
# Melhores resultados detalhados:
#         Modelo  Contexto  Dimensão Embedding  Épocas  Workers  PCA Aplicado  \
# 576       CBOW         2                 100       3        3          True
# 696       CBOW         3                 100       3        3          True
# 816       CBOW         4                 100       3        3          True
# 936       CBOW         5                 100       3        3          True
# 582       CBOW         2                 100       5        3          True
# 577       CBOW         2                 100       3        3          True
# 697       CBOW         3                 100       3        3          True
# 817       CBOW         4                 100       3        3          True
# 937       CBOW         5                 100       3        3          True
# 702       CBOW         3                 100       5        3          True
# 583       CBOW         2                 100       5        3          True
# 96   Skip-gram         2                 100       3        3          True
# 703       CBOW         3                 100       5        3          True
# 578       CBOW         2                 100       3        3          True
# 698       CBOW         3                 100       3        3          True
#
#     Componentes PCA  Distância Média
# 576               2         0.015313
# 696               2         0.015499
# 816               2         0.016060
# 936               2         0.016917
# 582               2         0.017851
# 577               3         0.019645
# 697               3         0.019893
# 817               3         0.020398
# 937               3         0.021197
# 702               2         0.021291
# 583               3         0.022070
# 96                2         0.023801
# 703               3         0.025309
# 578               5         0.025873
# 698               5         0.026093

# %%
print("Piores resultados detalhados:")
results_df.tail(15)
# Out:
# Piores resultados detalhados:
#         Modelo  Contexto  Dimensão Embedding  Épocas  Workers  PCA Aplicado  \
# 254  Skip-gram         4                   5       7        3          True
# 255  Skip-gram         4                   5       7        3         False
# 429  Skip-gram         5                  25      10        3         False
# 141  Skip-gram         3                   5      10        3         False
# 140  Skip-gram         3                   5      10        3          True
# 259  Skip-gram         4                   5      10        3          True
# 405  Skip-gram         5                  20      10        3         False
# 375  Skip-gram         5                   5       7        3         False
# 374  Skip-gram         5                   5       7        3          True
# 378  Skip-gram         5                   5      10        3          True
# 379  Skip-gram         5                   5      10        3          True
# 260  Skip-gram         4                   5      10        3          True
# 261  Skip-gram         4                   5      10        3         False
# 380  Skip-gram         5                   5      10        3          True
# 381  Skip-gram         5                   5      10        3         False
#
#     Componentes PCA  Distância Média
# 254               5         0.682484
# 255    Não Aplicado         0.682484
# 429    Não Aplicado         0.706738
# 141    Não Aplicado         0.712586
# 140               5         0.712586
# 259               3         0.720624
# 405    Não Aplicado         0.729864
# 375    Não Aplicado         0.742025
# 374               5         0.742025
# 378               2         0.753533
# 379               3         0.805487
# 260               5         0.812734
# 261    Não Aplicado         0.812734
# 380               5         0.892421
# 381    Não Aplicado         0.892421

# %% [markdown]
# A partir desses resultados, tem-se que:
#
# 1. **Modelos (CBOW vs Skip-gram)**
#
# CBOW apresenta valores significativamente menores para a distância média, indicando melhor desempenho na tarefa de prever analogias. Já o Skip-gram possui maiores distâncias médias, o que sugere menor precisão. Isso pode ocorrer por que o Skip-Gram, apesar de ser comumente mais eficaz em representar palavras raras, mas menos eficiente em tarefas gerais com vocabulário limitado.
#
# 2. **Tamanho do Contexto**
#
# Para CBOW, o contexto 2 tem distâncias médias melhores (menores) em comparação aos demais tamanho de contexto.
#
# 3. **Dimensão do Embedding**
#
# Para CBOW, embeddings de dimensão 100 consistentemente apresentam as menores distâncias médias, indicando que maior dimensionalidade captura melhor as relações semânticas. Dimensões mais baixas (como 5) parecem inadequadas para ambas as abordagens, com resultados menos precisos.
#
# 4. **Número de Épocas**
#
# Para CBOW, o número de épocas 3 é suficiente para alcançar boas distâncias médias, sugerindo que o modelo converge rapidamente. Assim como ocorre com o Skip-Gram, é possível perceber que números maiores de época prejudicam o modelo.
#
# * **PCA**
#
# Os resultados foram consistentemente melhores quando houve a aplicação do PCA, especialmente com 2 componentes. Isso pode indicar que um espaço reduzido pode ser suficiente para representar as relações semânticas essenciais das analogias. Para o Skip-Gram, a aplicação do PCA não parece surtir tanto efeito em alguns resultados, de forma que seu uso se torna desnecessário.
#
# Assim, tem-se que a melhor configuração é:
# * Modelo: CBOW
# * Tamanho do Contexto: 2
# * Dimensão do Embedding: 100
# * PCA: aplicado, com 2 componentes
# * Épocas: 3
#
# Essa configuração apresentação a menor distância média dentre os modelos avalidos, sendo ela **0.021291**.

# %% [markdown]
# ## Avaliação com Modelo Nulo
#
# Aqui, considera-se o modelo nulo como o modelo Word2Vec executado com os parâmetros padrão da implementação da biblioteca, dado o mesmo corpus. A intenção é identificar se há diferença entre os resultados calculados pelo modelo identificado pela Grid Search ou não.

# %%
# Comparação com o modelo padrão
default_model = Word2Vec(
    sentences=corpus,
    vector_size=100,
    window=5,
    sg=0,  # 'CBOW' por padrão
    epochs=5,
    workers=3
)
default_avg_distance = evaluate_distance(default_model, analogy_path, False)
min_distance_model = results_df["Distância Média"].min()

print("\n--- Comparação entre Modelo Padrão e Melhor Modelo ---")
print(f"Distância Média do Modelo Padrão ('CBOW', 5, 100, 3, False, -, 3): {default_avg_distance:.4f}")
print(f"Melhores Parâmetros do Grid Search: {best_params}, Distância Média: {min_distance_model:.4f}")

if default_avg_distance > min_distance_model:
    improvement = ((default_avg_distance - min_distance_model) / default_avg_distance) * 100
    print(f"\nO modelo treinado com Grid Search possui distância mínima média {improvement:.2f}% menor que o modelo padrão.")
else:
    improvement = ((min_distance_model - default_avg_distance) / min_distance_model) * 100
    print(f"\nO modelo padrão possui distância mínima média {improvement:.2f}% menor que o modelo treinado com Grid Search.")
# Out:
# --- Comparação entre Modelo Padrão e Melhor Modelo ---
# Distância Média do Modelo Padrão ('CBOW', 5, 100, 3, False, -, 3): 0.1257
# Melhores Parâmetros do Grid Search: ('CBOW', 2, 100, 3, True, 2, 3), Distância Média: 0.0153
#
# O modelo treinado com Grid Search possui distância mínima média 87.82% menor que o modelo padrão.

# %% [markdown]
# # Referências Bibliográficas
#
# Jiménez, Á.B., Lázaro, J.L., Dorronsoro, J.R. (2007). Finding Optimal Model Parameters by Discrete Grid Search. In: Corchado, E., Corchado, J.M., Abraham, A. (eds) Innovations in Hybrid Intelligent Systems. Advances in Soft Computing, vol 44. Springer, Berlin, Heidelberg. https://doi.org/10.1007/978-3-540-74972-1_17
#
# Kurita, T. (2020). Principal Component Analysis (PCA). In: Computer Vision. Springer, Cham. https://doi.org/10.1007/978-3-030-03243-2_649-1
#
# Mahoney, Matt (2011). About the Test Data. Matt Mahoney. https://mattmahoney.net/dc/textdata.html
#
# McCornick, Chris (2016). Word2Vec Resources. Chris McCormick. https://mccormickml.com/2016/04/27/word2vec-resources/
#
# _ (2024). Word Embedding using Word2Vec. Geeks for Geeks. https://www.geeksforgeeks.org/python-word-embedding-using-word2vec/
